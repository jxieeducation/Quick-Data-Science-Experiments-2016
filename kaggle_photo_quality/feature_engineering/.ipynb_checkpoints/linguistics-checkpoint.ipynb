# %%
import numpy as np 
import pandas as pd 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv("../data/training.csv")

# %%
def generate_word_matrix(train_ling):
    word_list = [str(line).split() for line in train_ling]
    refined_list = []
    max_elem = -1
    for str_list in word_list:
        int_list = [int(elem) for elem in str_list if elem != "nan"]
        for i in int_list:
            if i > max_elem:
                max_elem = i
        refined_list += [int_list]
    refined_list = np.array(refined_list)

    word_np = np.zeros((refined_list.shape[0], max_elem))
    for i, int_list in enumerate(refined_list):
        for num in int_list:
            word_np[i][num-1] = 1
    return word_np

# %%
name_np = generate_word_matrix(train.name)
description_np = generate_word_matrix(train.description)
caption_np = generate_word_matrix(train.caption)
print name_np.shape
print description_np.shape
print caption_np.shape
# Out:
# (40262, 2151)
# (40262, 2151)
# (40262, 2151)

# %%
X_no_ling = train[["latitude", "longitude", "width", "height", "size"]]
y = train.good
X_full = np.concatenate((X_no_ling.values, name_np, description_np, caption_np), axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier

def benchmark(X, y, max_depth):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    rf = RandomForestClassifier(n_estimators=50, max_depth=max_depth, n_jobs=-1)
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    return 1 - accuracy_score(y_test, pred)

# %%
print benchmark(X_full, y, 50)
# Out:
# 0.235342816287
# None

# %%
import xgboost as xgb

def xgb_benchmark(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist  = [(dtest,'eval'), (dtrain,'train')]
    param = {'bst:max_depth':20, 'bst:eta':0.05, 'silent':1, 
             'objective':'binary:logistic', 'early_stopping_rounds':10,
             'subsample': 0.7, 'colsample_bytree': 0.1, 'min_child_weight': 1.05
            }
    param['nthread'] = 4
    param['eval_metric'] = 'auc'
    num_round = 500
    bst = xgb.train(param, dtrain, num_round, evallist )
    bst.save_model("../data/xgb.model")
    pred = bst.predict(dtest)
    pred[pred < 0.5] = 0
    pred[pred >= 0.5] = 1
    return (1 - accuracy_score(y_test, pred)), bst

# %%
acc, bst = xgb_benchmark(X_full, y)
print acc
# Out:
# [0]	eval-auc:0.683320	train-auc:0.728685
# [1]	eval-auc:0.711972	train-auc:0.759746
# [2]	eval-auc:0.720245	train-auc:0.767467
# [3]	eval-auc:0.728608	train-auc:0.781279
# [4]	eval-auc:0.737777	train-auc:0.787784
# [5]	eval-auc:0.740045	train-auc:0.788618
# [6]	eval-auc:0.747737	train-auc:0.797262
# [7]	eval-auc:0.749427	train-auc:0.799234
# [8]	eval-auc:0.752636	train-auc:0.802097
# [9]	eval-auc:0.754801	train-auc:0.804191
# [10]	eval-auc:0.759667	train-auc:0.812099
# [11]	eval-auc:0.762034	train-auc:0.816251
# [12]	eval-auc:0.763134	train-auc:0.816563
# [13]	eval-auc:0.765471	train-auc:0.819354
# [14]	eval-auc:0.767418	train-auc:0.821195
# [15]	eval-auc:0.769504	train-auc:0.823186
# [16]	eval-auc:0.771805	train-auc:0.825391
# [17]	eval-auc:0.773066	train-auc:0.826592
# [18]	eval-auc:0.774523	train-auc:0.828606
# [19]	eval-auc:0.774844	train-auc:0.829087
# [20]	eval-auc:0.777955	train-auc:0.830310
# [21]	eval-auc:0.778268	train-auc:0.830774
# [22]	eval-auc:0.780592	train-auc:0.831969
# [23]	eval-auc:0.782407	train-auc:0.835147
# [24]	eval-auc:0.783606	train-auc:0.836195
# [25]	eval-auc:0.784106	train-auc:0.836836
# [26]	eval-auc:0.784251	train-auc:0.839779
# [27]	eval-auc:0.787478	train-auc:0.845426
# [28]	eval-auc:0.788173	train-auc:0.845819
# [29]	eval-auc:0.788888	train-auc:0.846391
# [30]	eval-auc:0.790094	train-auc:0.848957
# [31]	eval-auc:0.791360	train-auc:0.849839
# [32]	eval-auc:0.792620	train-auc:0.851078
# [33]	eval-auc:0.792733	train-auc:0.851386
# [34]	eval-auc:0.793016	train-auc:0.851679
# [35]	eval-auc:0.794180	train-auc:0.852529
# [36]	eval-auc:0.792688	train-auc:0.852427
# [37]	eval-auc:0.793573	train-auc:0.852879
# [38]	eval-auc:0.794218	train-auc:0.853605
# [39]	eval-auc:0.794855	train-auc:0.854438
# [40]	eval-auc:0.795778	train-auc:0.855265
# [41]	eval-auc:0.796696	train-auc:0.856349
# [42]	eval-auc:0.797381	train-auc:0.856876
# [43]	eval-auc:0.798027	train-auc:0.857507
# [44]	eval-auc:0.798452	train-auc:0.857968
# [45]	eval-auc:0.798635	train-auc:0.858313
# [46]	eval-auc:0.799209	train-auc:0.858850
# [47]	eval-auc:0.799711	train-auc:0.860292
# [48]	eval-auc:0.800309	train-auc:0.860987
# [49]	eval-auc:0.800843	train-auc:0.862790
# [50]	eval-auc:0.801341	train-auc:0.865921
# [51]	eval-auc:0.801657	train-auc:0.866213
# [52]	eval-auc:0.802432	train-auc:0.866635
# [53]	eval-auc:0.802911	train-auc:0.867885
# [54]	eval-auc:0.803415	train-auc:0.868641
# [55]	eval-auc:0.803800	train-auc:0.870410
# [56]	eval-auc:0.804575	train-auc:0.871370
# [57]	eval-auc:0.804616	train-auc:0.871816
# [58]	eval-auc:0.805129	train-auc:0.872369
# [59]	eval-auc:0.805428	train-auc:0.873254
# [60]	eval-auc:0.805663	train-auc:0.873504
# [61]	eval-auc:0.806152	train-auc:0.874131
# [62]	eval-auc:0.805870	train-auc:0.874903
# [63]	eval-auc:0.806220	train-auc:0.875623
# [64]	eval-auc:0.806504	train-auc:0.875982
# [65]	eval-auc:0.807047	train-auc:0.876479
# [66]	eval-auc:0.807263	train-auc:0.876837
# [67]	eval-auc:0.807641	train-auc:0.876870
# [68]	eval-auc:0.808011	train-auc:0.877658
# [69]	eval-auc:0.808188	train-auc:0.878240
# [70]	eval-auc:0.808267	train-auc:0.878807
# [71]	eval-auc:0.808495	train-auc:0.879123
# [72]	eval-auc:0.808882	train-auc:0.879651
# [73]	eval-auc:0.809433	train-auc:0.880831
# [74]	eval-auc:0.809245	train-auc:0.880715
# [75]	eval-auc:0.809664	train-auc:0.881251
# [76]	eval-auc:0.809907	train-auc:0.881371
# [77]	eval-auc:0.810444	train-auc:0.882494
# [78]	eval-auc:0.810535	train-auc:0.882928
# [79]	eval-auc:0.810570	train-auc:0.882881
# [80]	eval-auc:0.810894	train-auc:0.883025
# [81]	eval-auc:0.811148	train-auc:0.883111
# [82]	eval-auc:0.811414	train-auc:0.883327
# [83]	eval-auc:0.811243	train-auc:0.884926
# [84]	eval-auc:0.811340	train-auc:0.885199
# [85]	eval-auc:0.811486	train-auc:0.885710
# [86]	eval-auc:0.811436	train-auc:0.886011
# [87]	eval-auc:0.811811	train-auc:0.886638
# [88]	eval-auc:0.811461	train-auc:0.887127
# [89]	eval-auc:0.811437	train-auc:0.887286
# [90]	eval-auc:0.811528	train-auc:0.887570
# [91]	eval-auc:0.811754	train-auc:0.887915
# [92]	eval-auc:0.811960	train-auc:0.888195
# [93]	eval-auc:0.812339	train-auc:0.888817
# [94]	eval-auc:0.812500	train-auc:0.889075
# [95]	eval-auc:0.812381	train-auc:0.889120
# [96]	eval-auc:0.812497	train-auc:0.889274
# [97]	eval-auc:0.812659	train-auc:0.889577
# [98]	eval-auc:0.812755	train-auc:0.889888
# [99]	eval-auc:0.812952	train-auc:0.890129
# [100]	eval-auc:0.813088	train-auc:0.890473
# [101]	eval-auc:0.812906	train-auc:0.890365
# [102]	eval-auc:0.813108	train-auc:0.890613
# [103]	eval-auc:0.813261	train-auc:0.890776
# [104]	eval-auc:0.813309	train-auc:0.891169
# [105]	eval-auc:0.813491	train-auc:0.891451
# [106]	eval-auc:0.813650	train-auc:0.891869
# [107]	eval-auc:0.813787	train-auc:0.892053
# [108]	eval-auc:0.813907	train-auc:0.892289
# [109]	eval-auc:0.814026	train-auc:0.892647
# [110]	eval-auc:0.814086	train-auc:0.892988
# [111]	eval-auc:0.814171	train-auc:0.893076
# [112]	eval-auc:0.814295	train-auc:0.893147
# [113]	eval-auc:0.814520	train-auc:0.893786
# [114]	eval-auc:0.814484	train-auc:0.894129
# [115]	eval-auc:0.814229	train-auc:0.893972
# [116]	eval-auc:0.814395	train-auc:0.894086
# [117]	eval-auc:0.814502	train-auc:0.894328
# [118]	eval-auc:0.814427	train-auc:0.894669
# [119]	eval-auc:0.814694	train-auc:0.894950
# [120]	eval-auc:0.814566	train-auc:0.895124
# [121]	eval-auc:0.814418	train-auc:0.895241
# [122]	eval-auc:0.814463	train-auc:0.895447
# [123]	eval-auc:0.814577	train-auc:0.895577
# [124]	eval-auc:0.814677	train-auc:0.895787
# [125]	eval-auc:0.814805	train-auc:0.895947
# [126]	eval-auc:0.814725	train-auc:0.896203
# [127]	eval-auc:0.814352	train-auc:0.896212
# [128]	eval-auc:0.814474	train-auc:0.896473
# [129]	eval-auc:0.814429	train-auc:0.896627
# [130]	eval-auc:0.814505	train-auc:0.896770
# [131]	eval-auc:0.814664	train-auc:0.897050
# [132]	eval-auc:0.814703	train-auc:0.897167
# [133]	eval-auc:0.814956	train-auc:0.897468
# [134]	eval-auc:0.815122	train-auc:0.897651
# [135]	eval-auc:0.815210	train-auc:0.897792
# [136]	eval-auc:0.815023	train-auc:0.898337
# [137]	eval-auc:0.815068	train-auc:0.898408
# [138]	eval-auc:0.815119	train-auc:0.898548
# [139]	eval-auc:0.815294	train-auc:0.899419
# [140]	eval-auc:0.815208	train-auc:0.899454
# [141]	eval-auc:0.815323	train-auc:0.900176
# [142]	eval-auc:0.815445	train-auc:0.900294
# [143]	eval-auc:0.815538	train-auc:0.900719
# [144]	eval-auc:0.815748	train-auc:0.900871
# [145]	eval-auc:0.815866	train-auc:0.901023
# [146]	eval-auc:0.815977	train-auc:0.901250
# [147]	eval-auc:0.816170	train-auc:0.901449
# [148]	eval-auc:0.816354	train-auc:0.901571
# [149]	eval-auc:0.816144	train-auc:0.902146
# [150]	eval-auc:0.816313	train-auc:0.902315
# [151]	eval-auc:0.816443	train-auc:0.902426
# [152]	eval-auc:0.816473	train-auc:0.902546
# [153]	eval-auc:0.816742	train-auc:0.903025
# [154]	eval-auc:0.816759	train-auc:0.903504
# [155]	eval-auc:0.816906	train-auc:0.903960
# [156]	eval-auc:0.816938	train-auc:0.904172
# [157]	eval-auc:0.817031	train-auc:0.904209
# [158]	eval-auc:0.816908	train-auc:0.904180
# [159]	eval-auc:0.817045	train-auc:0.904499
# [160]	eval-auc:0.817217	train-auc:0.904746
# [161]	eval-auc:0.817272	train-auc:0.905066
# [162]	eval-auc:0.817343	train-auc:0.905177
# [163]	eval-auc:0.817065	train-auc:0.905960
# [164]	eval-auc:0.817131	train-auc:0.906066
# [165]	eval-auc:0.817232	train-auc:0.906215
# [166]	eval-auc:0.817213	train-auc:0.906471
# [167]	eval-auc:0.817334	train-auc:0.906550
# [168]	eval-auc:0.817404	train-auc:0.906695
# [169]	eval-auc:0.817199	train-auc:0.906842
# [170]	eval-auc:0.817314	train-auc:0.906999
# [171]	eval-auc:0.817277	train-auc:0.907516
# [172]	eval-auc:0.817381	train-auc:0.907637
# [173]	eval-auc:0.817441	train-auc:0.907779
# [174]	eval-auc:0.817446	train-auc:0.907946
# [175]	eval-auc:0.817529	train-auc:0.908106
# [176]	eval-auc:0.817600	train-auc:0.908229
# [177]	eval-auc:0.817726	train-auc:0.908302
# [178]	eval-auc:0.817600	train-auc:0.908434
# [179]	eval-auc:0.817751	train-auc:0.908647
# [180]	eval-auc:0.817818	train-auc:0.908797
# [181]	eval-auc:0.817859	train-auc:0.909136
# [182]	eval-auc:0.817991	train-auc:0.909265
# [183]	eval-auc:0.818000	train-auc:0.909408
# [184]	eval-auc:0.817949	train-auc:0.909477
# [185]	eval-auc:0.817978	train-auc:0.909711
# [186]	eval-auc:0.818114	train-auc:0.910795
# [187]	eval-auc:0.818133	train-auc:0.910941
# [188]	eval-auc:0.818186	train-auc:0.911153
# [189]	eval-auc:0.818222	train-auc:0.911265
# [190]	eval-auc:0.818185	train-auc:0.911357
# [191]	eval-auc:0.818282	train-auc:0.911530
# [192]	eval-auc:0.818406	train-auc:0.911656
# [193]	eval-auc:0.818512	train-auc:0.911812
# [194]	eval-auc:0.818671	train-auc:0.912027
# [195]	eval-auc:0.818670	train-auc:0.912303
# [196]	eval-auc:0.818756	train-auc:0.912439
# [197]	eval-auc:0.818721	train-auc:0.912724
# [198]	eval-auc:0.818723	train-auc:0.912806
# [199]	eval-auc:0.818847	train-auc:0.912936
# [200]	eval-auc:0.818793	train-auc:0.913751
# [201]	eval-auc:0.818832	train-auc:0.913958
# [202]	eval-auc:0.818865	train-auc:0.914023
# [203]	eval-auc:0.818968	train-auc:0.914100
# [204]	eval-auc:0.818999	train-auc:0.914226
# [205]	eval-auc:0.819008	train-auc:0.914330
# [206]	eval-auc:0.819089	train-auc:0.914438
# [207]	eval-auc:0.819189	train-auc:0.914648
# [208]	eval-auc:0.819252	train-auc:0.914772
# [209]	eval-auc:0.819254	train-auc:0.914850
# [210]	eval-auc:0.819378	train-auc:0.914962
# [211]	eval-auc:0.819499	train-auc:0.915226
# [212]	eval-auc:0.819641	train-auc:0.915362
# [213]	eval-auc:0.819700	train-auc:0.915582
# [214]	eval-auc:0.819714	train-auc:0.915684
# [215]	eval-auc:0.819606	train-auc:0.915881
# [216]	eval-auc:0.819629	train-auc:0.916090
# [217]	eval-auc:0.819562	train-auc:0.916126
# [218]	eval-auc:0.819586	train-auc:0.916155
# [219]	eval-auc:0.819660	train-auc:0.916237
# [220]	eval-auc:0.819753	train-auc:0.916361
# [221]	eval-auc:0.819821	train-auc:0.916494
# [222]	eval-auc:0.819855	train-auc:0.916800
# [223]	eval-auc:0.819892	train-auc:0.916888
# [224]	eval-auc:0.819900	train-auc:0.917049
# [225]	eval-auc:0.819943	train-auc:0.917120
# [226]	eval-auc:0.819996	train-auc:0.917193
# [227]	eval-auc:0.820008	train-auc:0.917266
# [228]	eval-auc:0.820092	train-auc:0.917315
# [229]	eval-auc:0.820178	train-auc:0.917427
# [230]	eval-auc:0.820206	train-auc:0.917500
# [231]	eval-auc:0.820154	train-auc:0.917562
# [232]	eval-auc:0.820155	train-auc:0.917844
# [233]	eval-auc:0.820188	train-auc:0.917907
# [234]	eval-auc:0.820287	train-auc:0.918040
# [235]	eval-auc:0.820311	train-auc:0.918192
# [236]	eval-auc:0.820315	train-auc:0.918502
# [237]	eval-auc:0.820387	train-auc:0.918606
# [238]	eval-auc:0.820455	train-auc:0.918715
# [239]	eval-auc:0.820546	train-auc:0.920263
# [240]	eval-auc:0.820550	train-auc:0.920377
# [241]	eval-auc:0.820627	train-auc:0.920468
# [242]	eval-auc:0.820634	train-auc:0.920519
# [243]	eval-auc:0.821019	train-auc:0.921003
# [244]	eval-auc:0.821065	train-auc:0.921097
# [245]	eval-auc:0.821113	train-auc:0.921167
# [246]	eval-auc:0.821108	train-auc:0.921235
# [247]	eval-auc:0.821162	train-auc:0.921282
# [248]	eval-auc:0.821200	train-auc:0.921357
# [249]	eval-auc:0.821214	train-auc:0.921386
# [250]	eval-auc:0.821151	train-auc:0.921536
# [251]	eval-auc:0.821196	train-auc:0.921686
# [252]	eval-auc:0.821190	train-auc:0.921819
# [253]	eval-auc:0.821244	train-auc:0.921910
# [254]	eval-auc:0.821327	train-auc:0.922215
# [255]	eval-auc:0.821416	train-auc:0.922316
# [256]	eval-auc:0.821444	train-auc:0.923107
# [257]	eval-auc:0.821661	train-auc:0.923913
# [258]	eval-auc:0.821698	train-auc:0.924051
# [259]	eval-auc:0.821778	train-auc:0.924081
# [260]	eval-auc:0.821783	train-auc:0.924160
# [261]	eval-auc:0.821867	train-auc:0.924277
# [262]	eval-auc:0.821894	train-auc:0.924496
# [263]	eval-auc:0.821852	train-auc:0.924654
# [264]	eval-auc:0.821845	train-auc:0.924751
# [265]	eval-auc:0.821798	train-auc:0.924925
# [266]	eval-auc:0.821849	train-auc:0.924997
# [267]	eval-auc:0.821883	train-auc:0.925048
# [268]	eval-auc:0.821939	train-auc:0.925103
# [269]	eval-auc:0.821844	train-auc:0.925245
# [270]	eval-auc:0.821836	train-auc:0.925409
# [271]	eval-auc:0.821863	train-auc:0.926106
# [272]	eval-auc:0.821861	train-auc:0.926373
# [273]	eval-auc:0.821904	train-auc:0.926438
# [274]	eval-auc:0.821903	train-auc:0.926475
# [275]	eval-auc:0.821927	train-auc:0.926526
# [276]	eval-auc:0.821782	train-auc:0.926608
# [277]	eval-auc:0.821772	train-auc:0.926680
# [278]	eval-auc:0.821761	train-auc:0.926738
# [279]	eval-auc:0.821766	train-auc:0.926797
# [280]	eval-auc:0.821815	train-auc:0.926889
# [281]	eval-auc:0.821853	train-auc:0.926941
# [282]	eval-auc:0.821900	train-auc:0.927043
# [283]	eval-auc:0.821897	train-auc:0.927180
# [284]	eval-auc:0.821909	train-auc:0.927425
# [285]	eval-auc:0.822006	train-auc:0.927598
# [286]	eval-auc:0.822102	train-auc:0.927662
# [287]	eval-auc:0.822081	train-auc:0.927802
# [288]	eval-auc:0.822097	train-auc:0.927888
# [289]	eval-auc:0.822151	train-auc:0.928844
# [290]	eval-auc:0.822136	train-auc:0.928942
# [291]	eval-auc:0.822164	train-auc:0.929011
# [292]	eval-auc:0.822193	train-auc:0.929069
# [293]	eval-auc:0.822220	train-auc:0.929122
# [294]	eval-auc:0.822230	train-auc:0.929213
# [295]	eval-auc:0.822281	train-auc:0.929235
# [296]	eval-auc:0.822345	train-auc:0.929329
# [297]	eval-auc:0.822412	train-auc:0.929442
# [298]	eval-auc:0.822450	train-auc:0.929521
# [299]	eval-auc:0.822478	train-auc:0.929746
# [300]	eval-auc:0.822442	train-auc:0.929812
# [301]	eval-auc:0.822449	train-auc:0.929854
# [302]	eval-auc:0.822429	train-auc:0.929919
# [303]	eval-auc:0.822420	train-auc:0.930065
# [304]	eval-auc:0.822431	train-auc:0.930111
# [305]	eval-auc:0.822446	train-auc:0.930192
# [306]	eval-auc:0.822442	train-auc:0.930318
# [307]	eval-auc:0.822453	train-auc:0.930436
# [308]	eval-auc:0.822487	train-auc:0.930513
# [309]	eval-auc:0.822518	train-auc:0.930571
# [310]	eval-auc:0.822569	train-auc:0.930682
# [311]	eval-auc:0.822535	train-auc:0.930728
# [312]	eval-auc:0.822459	train-auc:0.930807
# [313]	eval-auc:0.822468	train-auc:0.930862
# [314]	eval-auc:0.822462	train-auc:0.931000
# [315]	eval-auc:0.822393	train-auc:0.931865
# [316]	eval-auc:0.822273	train-auc:0.932637
# [317]	eval-auc:0.822324	train-auc:0.932690
# [318]	eval-auc:0.822353	train-auc:0.932720
# [319]	eval-auc:0.822322	train-auc:0.932780
# [320]	eval-auc:0.822405	train-auc:0.932842
# [321]	eval-auc:0.822467	train-auc:0.932935
# [322]	eval-auc:0.822491	train-auc:0.933033
# [323]	eval-auc:0.822486	train-auc:0.933092
# [324]	eval-auc:0.822474	train-auc:0.933145
# [325]	eval-auc:0.822459	train-auc:0.933176
# [326]	eval-auc:0.822524	train-auc:0.933218
# [327]	eval-auc:0.822496	train-auc:0.933359
# [328]	eval-auc:0.822452	train-auc:0.933419
# [329]	eval-auc:0.822480	train-auc:0.933534
# [330]	eval-auc:0.822461	train-auc:0.933613
# [331]	eval-auc:0.822494	train-auc:0.933638
# [332]	eval-auc:0.822500	train-auc:0.933746
# [333]	eval-auc:0.822513	train-auc:0.933760
# [334]	eval-auc:0.822501	train-auc:0.933904
# [335]	eval-auc:0.822487	train-auc:0.933958
# [336]	eval-auc:0.822542	train-auc:0.933982
# [337]	eval-auc:0.822551	train-auc:0.934062
# [338]	eval-auc:0.822587	train-auc:0.934095
# [339]	eval-auc:0.822649	train-auc:0.934149
# [340]	eval-auc:0.822753	train-auc:0.934290
# [341]	eval-auc:0.822737	train-auc:0.934330
# [342]	eval-auc:0.822728	train-auc:0.934372
# [343]	eval-auc:0.822746	train-auc:0.934422
# [344]	eval-auc:0.822771	train-auc:0.934468
# [345]	eval-auc:0.822772	train-auc:0.934528
# [346]	eval-auc:0.822795	train-auc:0.934649
# [347]	eval-auc:0.822900	train-auc:0.934693
# [348]	eval-auc:0.822947	train-auc:0.934790
# [349]	eval-auc:0.822921	train-auc:0.934844
# [350]	eval-auc:0.822840	train-auc:0.934896
# [351]	eval-auc:0.822844	train-auc:0.934927
# [352]	eval-auc:0.822894	train-auc:0.935032
# [353]	eval-auc:0.822923	train-auc:0.935178
# [354]	eval-auc:0.822855	train-auc:0.935226
# [355]	eval-auc:0.822984	train-auc:0.935297
# [356]	eval-auc:0.823040	train-auc:0.935341
# [357]	eval-auc:0.823067	train-auc:0.935385
# [358]	eval-auc:0.823044	train-auc:0.935449
# [359]	eval-auc:0.823099	train-auc:0.935683
# [360]	eval-auc:0.823100	train-auc:0.935744
# [361]	eval-auc:0.823073	train-auc:0.935759
# [362]	eval-auc:0.823138	train-auc:0.935839
# [363]	eval-auc:0.823183	train-auc:0.936033
# [364]	eval-auc:0.823190	train-auc:0.936131
# [365]	eval-auc:0.823190	train-auc:0.936162
# [366]	eval-auc:0.823180	train-auc:0.936223
# [367]	eval-auc:0.823202	train-auc:0.936270
# [368]	eval-auc:0.823216	train-auc:0.936306
# [369]	eval-auc:0.823139	train-auc:0.936392
# [370]	eval-auc:0.823175	train-auc:0.936459
# [371]	eval-auc:0.823232	train-auc:0.937066
# [372]	eval-auc:0.823259	train-auc:0.937108
# [373]	eval-auc:0.823228	train-auc:0.937150
# [374]	eval-auc:0.823256	train-auc:0.937347
# [375]	eval-auc:0.823325	train-auc:0.937423
# [376]	eval-auc:0.823333	train-auc:0.937489
# [377]	eval-auc:0.823376	train-auc:0.937534
# [378]	eval-auc:0.823392	train-auc:0.937613
# [379]	eval-auc:0.823472	train-auc:0.937642
# [380]	eval-auc:0.823536	train-auc:0.937898
# [381]	eval-auc:0.823533	train-auc:0.937963
# [382]	eval-auc:0.823560	train-auc:0.938010
# [383]	eval-auc:0.823571	train-auc:0.938091
# [384]	eval-auc:0.823602	train-auc:0.938239
# [385]	eval-auc:0.823690	train-auc:0.939505
# [386]	eval-auc:0.823709	train-auc:0.939537
# [387]	eval-auc:0.823710	train-auc:0.939623
# [388]	eval-auc:0.823656	train-auc:0.939710
# [389]	eval-auc:0.823611	train-auc:0.939817
# [390]	eval-auc:0.823594	train-auc:0.939948
# [391]	eval-auc:0.823547	train-auc:0.940035
# [392]	eval-auc:0.823548	train-auc:0.940088
# [393]	eval-auc:0.823559	train-auc:0.940134
# [394]	eval-auc:0.823585	train-auc:0.940175
# [395]	eval-auc:0.823629	train-auc:0.940235
# [396]	eval-auc:0.823670	train-auc:0.940279
# [397]	eval-auc:0.823684	train-auc:0.940310
# [398]	eval-auc:0.823682	train-auc:0.940346
# [399]	eval-auc:0.823723	train-auc:0.940373
# [400]	eval-auc:0.823789	train-auc:0.940417
# [401]	eval-auc:0.823749	train-auc:0.940558
# [402]	eval-auc:0.823760	train-auc:0.940585
# [403]	eval-auc:0.823778	train-auc:0.940661
# [404]	eval-auc:0.823839	train-auc:0.940819
# [405]	eval-auc:0.823867	train-auc:0.940851
# [406]	eval-auc:0.823807	train-auc:0.940914
# [407]	eval-auc:0.823868	train-auc:0.940983
# [408]	eval-auc:0.823870	train-auc:0.941017
# [409]	eval-auc:0.823998	train-auc:0.940991
# [410]	eval-auc:0.824068	train-auc:0.941092
# [411]	eval-auc:0.824096	train-auc:0.941156
# [412]	eval-auc:0.824102	train-auc:0.941217
# [413]	eval-auc:0.824150	train-auc:0.941262
# [414]	eval-auc:0.824155	train-auc:0.941296
# [415]	eval-auc:0.824127	train-auc:0.941304
# [416]	eval-auc:0.824112	train-auc:0.941332
# [417]	eval-auc:0.824115	train-auc:0.941371
# [418]	eval-auc:0.824023	train-auc:0.941660
# [419]	eval-auc:0.824011	train-auc:0.941695
# [420]	eval-auc:0.823995	train-auc:0.941749
# [421]	eval-auc:0.824024	train-auc:0.941767
# [422]	eval-auc:0.824025	train-auc:0.942294
# [423]	eval-auc:0.824004	train-auc:0.942423
# [424]	eval-auc:0.824037	train-auc:0.942438
# [425]	eval-auc:0.824051	train-auc:0.942472
# [426]	eval-auc:0.824064	train-auc:0.942502
# [427]	eval-auc:0.824130	train-auc:0.942548
# [428]	eval-auc:0.824134	train-auc:0.942593
# [429]	eval-auc:0.824187	train-auc:0.942617
# [430]	eval-auc:0.824245	train-auc:0.942624
# [431]	eval-auc:0.824264	train-auc:0.942641
# [432]	eval-auc:0.824292	train-auc:0.942687
# [433]	eval-auc:0.824295	train-auc:0.942737
# [434]	eval-auc:0.824316	train-auc:0.942794
# [435]	eval-auc:0.824348	train-auc:0.942855
# [436]	eval-auc:0.824367	train-auc:0.942891
# [437]	eval-auc:0.824467	train-auc:0.942962
# [438]	eval-auc:0.824477	train-auc:0.943056
# [439]	eval-auc:0.824513	train-auc:0.943104
# [440]	eval-auc:0.824566	train-auc:0.943133
# [441]	eval-auc:0.824569	train-auc:0.943210
# [442]	eval-auc:0.824646	train-auc:0.943235
# [443]	eval-auc:0.824650	train-auc:0.943285
# [444]	eval-auc:0.824634	train-auc:0.943380
# [445]	eval-auc:0.824632	train-auc:0.943418
# [446]	eval-auc:0.824653	train-auc:0.943424
# [447]	eval-auc:0.824659	train-auc:0.943447
# [448]	eval-auc:0.824636	train-auc:0.943541
# [449]	eval-auc:0.824607	train-auc:0.943564
# [450]	eval-auc:0.824579	train-auc:0.943657
# [451]	eval-auc:0.824590	train-auc:0.943711
# [452]	eval-auc:0.824597	train-auc:0.943769
# [453]	eval-auc:0.824608	train-auc:0.943844
# [454]	eval-auc:0.824617	train-auc:0.943915
# [455]	eval-auc:0.824563	train-auc:0.943962
# [456]	eval-auc:0.824593	train-auc:0.943979
# [457]	eval-auc:0.824585	train-auc:0.944016
# [458]	eval-auc:0.824593	train-auc:0.944060
# [459]	eval-auc:0.824539	train-auc:0.944137
# [460]	eval-auc:0.824573	train-auc:0.944164
# [461]	eval-auc:0.824579	train-auc:0.944227
# [462]	eval-auc:0.824584	train-auc:0.944285
# [463]	eval-auc:0.824621	train-auc:0.944292
# [464]	eval-auc:0.824596	train-auc:0.944357
# [465]	eval-auc:0.824558	train-auc:0.944446
# [466]	eval-auc:0.824555	train-auc:0.944482
# [467]	eval-auc:0.824534	train-auc:0.944501
# [468]	eval-auc:0.824552	train-auc:0.944524
# [469]	eval-auc:0.824549	train-auc:0.944624
# [470]	eval-auc:0.824543	train-auc:0.944679
# [471]	eval-auc:0.824508	train-auc:0.944757
# [472]	eval-auc:0.824509	train-auc:0.944811
# [473]	eval-auc:0.824519	train-auc:0.944833
# [474]	eval-auc:0.824365	train-auc:0.945555
# [475]	eval-auc:0.824383	train-auc:0.945579
# [476]	eval-auc:0.824357	train-auc:0.945647
# [477]	eval-auc:0.824359	train-auc:0.945668
# [478]	eval-auc:0.824390	train-auc:0.945697
# [479]	eval-auc:0.824387	train-auc:0.945733
# [480]	eval-auc:0.824397	train-auc:0.945759
# [481]	eval-auc:0.824428	train-auc:0.945845
# [482]	eval-auc:0.824429	train-auc:0.945898
# [483]	eval-auc:0.824418	train-auc:0.945953
# [484]	eval-auc:0.824445	train-auc:0.946068
# [485]	eval-auc:0.824408	train-auc:0.946088
# [486]	eval-auc:0.824420	train-auc:0.946245
# [487]	eval-auc:0.824432	train-auc:0.946338
# [488]	eval-auc:0.824444	train-auc:0.946962
# [489]	eval-auc:0.824471	train-auc:0.946964
# [490]	eval-auc:0.824493	train-auc:0.946979
# [491]	eval-auc:0.824496	train-auc:0.946998
# [492]	eval-auc:0.824539	train-auc:0.947008
# [493]	eval-auc:0.824546	train-auc:0.947066
# [494]	eval-auc:0.824580	train-auc:0.947089
# [495]	eval-auc:0.824547	train-auc:0.947127
# [496]	eval-auc:0.824483	train-auc:0.947169
# [497]	eval-auc:0.824493	train-auc:0.947190
# 0.202152479868
# [498]	eval-auc:0.824480	train-auc:0.947253
# [499]	eval-auc:0.824482	train-auc:0.947307

# %%
test = pd.read_csv("../data/test.csv")
name_np = generate_word_matrix(test.name)
description_np = generate_word_matrix(test.description)
caption_np = generate_word_matrix(test.caption)
t_X_no_ling = test[["latitude", "longitude", "width", "height", "size"]]
t_X_full = np.concatenate((t_X_no_ling.values, name_np, description_np, caption_np), axis=1)

dtest = xgb.DMatrix(t_X_full)
pred = bst.predict(dtest)
pred[pred < 0.5] = 0
pred[pred >= 0.5] = 1
f = open("../data/submission.csv", 'w')
for i in pred:
    f.write(str(i))
    f.write("\n")
